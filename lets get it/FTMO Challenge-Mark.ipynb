# %% [markdown]
# ## FTMO Challenge Algorithm
#
# ### FTMO Parameters:
# - 10% DD for Phases 1, 2 and afterwards. 5% max daily drawdown
# - 10% Return for Phase 1, 5% return for Phase.
#
# ### Approach:
#
# FTMO's Asset universe includes Equities, Indices, Crypto, Commodities and Forex. The following portfolio strategies will be applied to each one:
# - **Equities** : MVO. 40% of portfolio
# - **Forex** : Quantitative Allocation. 40% of portfolio
# - **Indices, Crypto and Commodities** : TAA. 20% of portfolio

# %% [markdown]
# ### Libraries

# %%
import MetaTrader5 as mt5 
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller 
from datetime import datetime
import requests
import pandas as pd
import numpy as np
import warnings
import json
warnings.filterwarnings("ignore")
mt5.initialize()
# Replace following with your MT5 Account Login
account=51434456 # 
password="9UpBvVzc"
server = 'ICMarkets-Demo'

def get_rates(pair1, timeframe, x):
    pair1 = pd.DataFrame(mt5.copy_rates_from_pos(pair1, timeframe, 0, x))
    pair1['time'] = pd.to_datetime(pair1['time'], unit = 's')
    return pair1[['time','open', 'high', 'low', 'close']].set_index('time')

# %% [markdown]
# # Equities

# %%
us = ['AAPL.NAS.a', 'AMZN.NAS.a', 'BABA.NYSE.a', 'BAC.NYSE.a', 'MVRS.NAS.a', 'GOOG.NAS.a', 
      'MSFT.NAS.a', 'NVDA.NAS.a', 'PFE.NYSE.a', 'RACE.NYSE.a', 'T.NYSE.a', 'V.NYSE.a', 
      'WMT.NYSE.a', 'ZM.NAS.a', 'TSLA.NAS.a', 'NFLX.NAS.a']

# %%
## Average expected return over the 20, 50 and 75 by a 40, 40 and 20 weighting
sym_data = {}
periods = [20, 50, 75]

for period in periods:
    for sym in us:
        sym_data[sym] = get_rates(sym, mt5.TIMEFRAME_H4, period)

    combined_data = pd.DataFrame({name: data['close'] for name, data in sym_data.items()})

    returns = combined_data.pct_change().dropna()
    
    mu = expected_returns.prices_from_returns(returns)
    
    S = risk_models.sample_cov(log_returns, frequency=4*6*5)
    
    print(f"For period {period}, mu list is:"
          f"\n"
          f"\n{mu.iloc[-1]}")
# Out:
# For period 20, mu list is:
#
# AAPL.NAS.a     1.040973
# AMZN.NAS.a     1.017626
# BABA.NYSE.a    0.948508
# BAC.NYSE.a     1.015019
# MVRS.NAS.a     1.034741
# GOOG.NAS.a     1.006155
# MSFT.NAS.a     0.995145
# NVDA.NAS.a     1.031462
# PFE.NYSE.a     0.863397
# RACE.NYSE.a    1.018329
# T.NYSE.a       0.983557
# V.NYSE.a       1.018263
# WMT.NYSE.a     0.977348
# ZM.NAS.a       1.032059
# TSLA.NAS.a     0.968635
# NFLX.NAS.a     0.992073
# Name: 2023-12-13 16:00:00, dtype: float64
# For period 50, mu list is:
#
# AAPL.NAS.a     1.081765
# AMZN.NAS.a     1.036778
# BABA.NYSE.a    0.826790
# BAC.NYSE.a     1.095560
# MVRS.NAS.a     1.054306
# GOOG.NAS.a     1.012921
# MSFT.NAS.a     1.041167
# NVDA.NAS.a     1.052192
# PFE.NYSE.a     0.840436
# RACE.NYSE.a    1.099395
# T.NYSE.a       1.020215
# V.NYSE.a       1.061149
# WMT.NYSE.a     0.913610
# ZM.NAS.a       1.114535
# TSLA.NAS.a     1.053443
# NFLX.NAS.a     1.081262
# Name: 2023-12-13 16:00:00, dtype: float64
# For period 75, mu list is:
#
# AAPL.NAS.a     1.126937
# AMZN.NAS.a     1.170214
# BABA.NYSE.a    0.881765
# BAC.NYSE.a     1.159711
# MVRS.NAS.a     1.078839
# GOOG.NAS.a     0.970533
# MSFT.NAS.a     1.142809
# NVDA.NAS.a     1.160742
# PFE.NYSE.a     0.851996
# RACE.NYSE.a    1.211610
# T.NYSE.a       1.037918
# V.NYSE.a       1.105256
# WMT.NYSE.a     0.949170
# ZM.NAS.a       1.124760
# TSLA.NAS.a     1.087248
# NFLX.NAS.a     1.160657
# Name: 2023-12-13 16:00:00, dtype: float64

# %%
mu
# Out:
#                      AAPL.NAS.a  AMZN.NAS.a  BABA.NYSE.a  BAC.NYSE.a  \
# time
# 2023-10-20 16:00:00    1.000000    1.000000     1.000000    1.000000
# 2023-10-20 20:00:00    0.991772    0.990047     0.999125    0.989200
# 2023-10-23 16:00:00    0.995909    1.011519     1.010749    0.979227
# 2023-10-23 20:00:00    0.992031    1.000949     1.004999    0.961690
# 2023-10-24 16:00:00    0.985444    1.001764     1.037495    0.956610
# ...                         ...         ...          ...         ...
# 2023-12-11 16:00:00    1.102725    1.151044     0.891514    1.162383
# 2023-12-11 20:00:00    1.107774    1.153283     0.891389    1.158958
# 2023-12-12 16:00:00    1.109742    1.159699     0.888389    1.158281
# 2023-12-12 20:00:00    1.115525    1.166503     0.890889    1.156324
# 2023-12-13 16:00:00    1.126610    1.170554     0.881890    1.158958
#
#                      MVRS.NAS.a  GOOG.NAS.a  MSFT.NAS.a  NVDA.NAS.a  \
# time
# 2023-10-20 16:00:00    1.000000    1.000000    1.000000    1.000000
# 2023-10-20 20:00:00    0.991547    0.988416    0.994607    0.994091
# 2023-10-23 16:00:00    1.019445    1.003982    1.013437    1.032451
# 2023-10-23 20:00:00    1.007360    0.997973    1.003626    1.031298
# 2023-10-24 16:00:00    1.001189    1.006661    0.999604    1.029569
# ...                         ...         ...         ...         ...
# 2023-12-11 16:00:00    1.038439    0.970171    1.124254    1.110036
# 2023-12-11 20:00:00    1.046089    0.974732    1.130165    1.117794
# 2023-12-12 16:00:00    1.060873    0.968723    1.134339    1.127834
# 2023-12-12 20:00:00    1.073761    0.966044    1.136258    1.142006
# 2023-12-13 16:00:00    1.078100    0.970533    1.142931    1.161558
#
#                      PFE.NYSE.a  RACE.NYSE.a  T.NYSE.a  V.NYSE.a  WMT.NYSE.a  \
# time
# 2023-10-20 16:00:00    1.000000     1.000000  1.000000  1.000000    1.000000
# 2023-10-20 20:00:00    0.993184     0.998361  0.989075  0.994373    0.995174
# 2023-10-23 16:00:00    1.011360     1.010914  0.965296  0.998977    1.008524
# 2023-10-23 20:00:00    0.998702     1.003681  0.958869  0.988319    1.008837
# 2023-10-24 16:00:00    0.985719     0.995839  0.993573  0.995012    1.021059
# ...                         ...          ...       ...       ...         ...
# 2023-12-11 16:00:00    0.925673     1.223984  1.070051  1.096048    0.938201
# 2023-12-11 20:00:00    0.927296     1.232038  1.067481  1.093917    0.946788
# 2023-12-12 16:00:00    0.929893     1.224043  1.057198  1.102443    0.945597
# 2023-12-12 20:00:00    0.927945     1.228962  1.052699  1.106152    0.947853
# 2023-12-13 16:00:00    0.851347     1.211855  1.037918  1.105427    0.948104
#
#                      ZM.NAS.a  TSLA.NAS.a  NFLX.NAS.a
# time
# 2023-10-20 16:00:00  1.000000    1.000000    1.000000
# 2023-10-20 20:00:00  0.991745    0.985164    0.990231
# 2023-10-23 16:00:00  0.999000    1.007767    0.999654
# 2023-10-23 20:00:00  0.986908    0.986001    1.006232
# 2023-10-24 16:00:00  0.995034    1.002418    1.013157
# ...                       ...         ...         ...
# 2023-12-11 16:00:00  1.181949    1.112827    1.154029
# 2023-12-11 20:00:00  1.170662    1.115106    1.135999
# 2023-12-12 16:00:00  1.152814    1.092782    1.141416
# 2023-12-12 20:00:00  1.146526    1.099758    1.143716
# 2023-12-13 16:00:00  1.124599    1.087108    1.160706
#
# [74 rows x 16 columns]

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef = EfficientFrontier(mu, S)
# ef.add_objective(lambda w: w @ S @ w, target=0.02**2)  # Target volatility squared (as variance)
weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[263], line 3
#       1 from pypfopt.efficient_frontier import EfficientFrontier
# ----> 3 ef = EfficientFrontier(mu, S)
#       4 # ef.add_objective(lambda w: w @ S @ w, target=0.02**2)  # Target volatility squared (as variance)
#       5 weights = ef.max_sharpe()
#
# File ~\anaconda3\lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:86, in EfficientFrontier.__init__(self, expected_returns, cov_matrix, weight_bounds, solver, verbose, solver_options)
#      84 # Inputs
#      85 self.cov_matrix = self._validate_cov_matrix(cov_matrix)
# ---> 86 self.expected_returns = self._validate_expected_returns(expected_returns)
#      87 self._max_return_value = None
#      88 self._market_neutral = None
#
# File ~\anaconda3\lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:127, in EfficientFrontier._validate_expected_returns(expected_returns)
#     125     return expected_returns.ravel()
#     126 else:
# --> 127     raise TypeError("expected_returns is not a series, list or array")
#
# TypeError: expected_returns is not a series, list or array

# %% [markdown]
# # Forex

# %% [markdown]
# # Other
